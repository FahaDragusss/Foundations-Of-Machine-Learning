# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
house_df = pd.read_csv("house_price_dataset.csv")
house_df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
house_df.plot.scatter(x = 'bedrooms', y= 'bathrooms')
house_df.plot.scatter(x = 'bedrooms', y= 'sqft_living')
house_df.plot.scatter(x = 'bedrooms', y= 'condition')
house_df.plot.scatter(x = 'bedrooms', y= 'floors')
house_df.plot.scatter(x = 'bedrooms', y= 'sqft_above')
# Out:
# <Axes: xlabel='bedrooms', ylabel='sqft_above'>

# %%
house_df.plot.scatter(x = 'bathrooms', y= 'sqft_living')
house_df.plot.scatter(x = 'bathrooms', y= 'floors')
house_df.plot.scatter(x = 'bathrooms', y= 'sqft_above')
# Out:
# <Axes: xlabel='bathrooms', ylabel='sqft_above'>

# %%
house_df.plot.scatter(x = 'sqft_living', y= 'floors')
house_df.plot.scatter(x = 'sqft_living', y= 'sqft_above')
# Out:
# <Axes: xlabel='sqft_living', ylabel='sqft_above'>

# %%
house_df.plot.scatter(x = 'condition', y= 'floors')
# Out:
# <Axes: xlabel='condition', ylabel='floors'>

# %%
house_df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df_filtered_row = house_df[house_df['price'] >= 1]
df_filtered_row.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.551000e+03  4551.000000  4551.000000   4551.000000  4.551000e+03
# mean   5.579059e+05     3.394639     2.155021   2132.372226  1.483528e+04
# std    5.639299e+05     0.904595     0.776351    955.949708  3.596408e+04
# min    7.800000e+03     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.262643e+05     3.000000     1.750000   1460.000000  5.000000e+03
# 50%    4.650000e+05     3.000000     2.250000   1970.000000  7.680000e+03
# 75%    6.575000e+05     4.000000     2.500000   2610.000000  1.097800e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4551.000000  4551.000000  4551.000000  4551.000000  4551.000000
# mean      1.512195     0.006592     0.234674     3.449352  1822.221710
# std       0.538531     0.080932     0.765373     0.675160   854.452888
# ...

# %%
df_filtered = house_df.drop(['waterfront','view','sqft_basement','sqft_above','floors','condition',
                             'street','yr_renovated','city','statezip','country','date','yr_built',
                             'sqft_lot','sqft_living'], axis= 1)
df_filtered
# Out:
#              price  bedrooms  bathrooms
# 0     3.130000e+05       3.0       1.50
# 1     2.384000e+06       5.0       2.50
# 2     3.420000e+05       3.0       2.00
# 3     4.200000e+05       3.0       2.25
# 4     5.500000e+05       4.0       2.50
# ...            ...       ...        ...
# 4595  3.081667e+05       3.0       1.75
# 4596  5.343333e+05       3.0       2.50
# 4597  4.169042e+05       3.0       2.50
# 4598  2.034000e+05       4.0       2.00
# 4599  2.206000e+05       3.0       2.50
#
# [4600 rows x 3 columns]

# %%
house_filtered = df_filtered[df_filtered['price'] >= 1]
house_filtered.insert(0,'X0', 1)
# house_filtered['age'] = 2014 - house_df['yr_built']
house_filtered
# Out:
#       X0         price  bedrooms  bathrooms
# 0      1  3.130000e+05       3.0       1.50
# 1      1  2.384000e+06       5.0       2.50
# 2      1  3.420000e+05       3.0       2.00
# 3      1  4.200000e+05       3.0       2.25
# 4      1  5.500000e+05       4.0       2.50
# ...   ..           ...       ...        ...
# 4595   1  3.081667e+05       3.0       1.75
# 4596   1  5.343333e+05       3.0       2.50
# 4597   1  4.169042e+05       3.0       2.50
# 4598   1  2.034000e+05       4.0       2.00
# 4599   1  2.206000e+05       3.0       2.50
#
# [4551 rows x 4 columns]

# %%
house_filtered.to_csv('house_price_dataset_handled.csv', index = False)
